# %%
import pandas as pd
import numpy as np
import mne
import os
import tkinter as tk
from tkinter import filedialog, messagebox
from tkinter import ttk

class EEGDataExtractorApp:
    def __init__(self, root):
        self.root = root
        self.root.title("EEG Data Extractor")
        self.root.geometry("800x600")  # 放大窗口大小

        # 创建一个框架来放置并排按钮
        button_frame = tk.Frame(root)
        button_frame.pack(pady=10)

        # 添加按钮
        self.load_tsv_button = tk.Button(button_frame, text="加载TSV文件", command=self.load_tsv_file)
        self.load_tsv_button.pack(side=tk.LEFT, padx=5)

        self.load_eeg_button = tk.Button(button_frame, text="选择EEG文件", command=self.load_eeg_file, state=tk.DISABLED)
        self.load_eeg_button.pack(side=tk.LEFT, padx=5)

        # 添加下拉菜单选择EEG数据格式
        self.eeg_format_label = tk.Label(root, text="选择EEG数据格式:")
        self.eeg_format_label.pack(pady=5)

        self.eeg_format = tk.StringVar()
        self.eeg_format.set(None)  # 默认无选择

        self.eeg_format_combobox = ttk.Combobox(root, textvariable=self.eeg_format, values=["edf", "fif", "vhdr", "bdf"])
        self.eeg_format_combobox.bind("<<ComboboxSelected>>", self.on_eeg_format_selected)
        self.eeg_format_combobox.pack(pady=5)

        # 添加按钮
        self.save_dir_button = tk.Button(root, text="选择保存目录", command=self.select_save_dir)
        self.save_dir_button.pack(pady=10)

        self.process_button = tk.Button(root, text="处理数据", command=self.process_data)
        self.process_button.pack(pady=10)

        self.close_button = tk.Button(root, text="关闭", command=self.close_app)
        self.close_button.pack(pady=10)

        # 用于存储保存目录
        self.save_dirs = {}

        self.tsv_file_path = None
        self.eeg_file_path = None
        self.output_dir = None

    def load_tsv_file(self):
        self.tsv_file_path = filedialog.askopenfilename(filetypes=[("TSV files", "*.tsv")])
        if self.tsv_file_path:
            self.show_tsv_preview()
            self.create_trial_type_buttons()
            messagebox.showinfo("信息", f"TSV 文件已加载: {self.tsv_file_path}")

    def show_tsv_preview(self):
        try:
            df = pd.read_csv(self.tsv_file_path, sep='\t')
            preview_data = df.head(10)
        except Exception as e:
            messagebox.showerror("错误", f"读取TSV文件时出现错误: {str(e)}")
            return

        # 创建一个新的窗口显示数据
        preview_window = tk.Toplevel(self.root)
        preview_window.title("TSV文件预览")
        preview_window.geometry("600x300")

        text_area = tk.Text(preview_window, wrap=tk.NONE)
        text_area.pack(expand=True, fill=tk.BOTH)

        text_area.insert(tk.END, preview_data.to_string(index=False))

    def create_trial_type_buttons(self):
        # 删除现有的 trial_type 按钮
        for widget in self.root.winfo_children():
            if isinstance(widget, tk.Button) and widget.cget("text").startswith("选择保存目录"):
                widget.destroy()

        if self.tsv_file_path:
            df = pd.read_csv(self.tsv_file_path, sep='\t')
            trial_types = df['trial_type'].unique()

            self.save_dirs = {}  # 重置保存目录字典

            for trial_type in trial_types:
                button = tk.Button(self.root, text=f"选择 {trial_type} 保存目录", command=lambda t=trial_type: self.select_save_dir(t))
                button.pack(pady=5)

    def select_save_dir(self, trial_type=None):
        if trial_type:
            dir_path = filedialog.askdirectory()
            if dir_path:
                self.save_dirs[trial_type] = dir_path
                messagebox.showinfo("信息", f"{trial_type} 保存目录已选择: {dir_path}")

    def load_eeg_file(self):
        eeg_format = self.eeg_format.get()
        if not eeg_format:
            messagebox.showerror("错误", "请先选择EEG数据格式")
            return

        filetypes = {
            'edf': ("EDF files", "*.edf"),
            'fif': ("FIF files", "*.fif"),
            'vhdr': ("BrainVision files", "*.vhdr"),
            'bdf': ("BDF files", "*.bdf")
        }
        
        selected_filetypes = filetypes.get(eeg_format, ("All files", "*.*"))
        self.eeg_file_path = filedialog.askopenfilename(filetypes=[selected_filetypes])

        if self.eeg_file_path:
            messagebox.showinfo("信息", f"EEG 文件已加载: {self.eeg_file_path}")

    def on_eeg_format_selected(self, event):
        # 当选择格式时启用加载EEG文件按钮
        self.load_eeg_button.config(state=tk.NORMAL)

    def process_data(self):
        if not self.tsv_file_path or not self.eeg_file_path or not self.save_dirs:
            messagebox.showerror("错误", "请确保已加载TSV文件、EEG文件，并选择所有试验类型的保存目录")
            return

        eeg_format = self.eeg_format.get()
        
        try:
            # 读取TSV文件
            events_df = pd.read_csv(self.tsv_file_path, sep='\t')
            onsets = events_df['onset'].values
            durations = events_df['duration'].values
            trial_types = events_df['trial_type'].values

            # 读取EEG数据
            if eeg_format == 'edf':
                eeg_data = mne.io.read_raw_edf(self.eeg_file_path, preload=True)
            elif eeg_format == 'fif':
                eeg_data = mne.io.read_raw_fif(self.eeg_file_path, preload=True)
            elif eeg_format == 'vhdr':
                eeg_data = mne.io.read_raw_brainvision(self.eeg_file_path, preload=True)
            elif eeg_format == 'bdf':
                eeg_data = mne.io.read_raw_bdf(self.eeg_file_path, preload=True)
            else:
                raise ValueError("不支持的EEG文件格式")

            sfreq = eeg_data.info['sfreq']

            # 提取并保存试验数据
            for i, (onset, duration, trial_type) in enumerate(zip(onsets, durations, trial_types)):
                start_idx = int(onset * sfreq)
                end_idx = int((onset + duration) * sfreq)
                trial_data = eeg_data.get_data(start=start_idx, stop=end_idx)

                # 使用 trial_type 来选择保存目录
                if trial_type in self.save_dirs:
                    file_name = f'trial_{i}_{trial_type}.npy'
                    file_path = os.path.join(self.save_dirs[trial_type], file_name)
                    np.save(file_path, trial_data)
                    print(f'Saved trial {i} ({trial_type}) to {file_path}')
                else:
                    messagebox.showwarning("警告", f"未为 trial_type '{trial_type}' 选择保存目录")

            messagebox.showinfo("完成", "所有试验数据已成功保存。")
        except Exception as e:
            messagebox.showerror("错误", f"处理数据时出现错误: {str(e)}")

    def close_app(self):
        self.root.destroy()

# 创建GUI应用程序
root = tk.Tk()
app = EEGDataExtractorApp(root)
root.mainloop()
# Out:
# Extracting EDF parameters from C:\Users\pc\Desktop\李佳\sub-001_ses-03_task_motorimagery_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 98999  =      0.000 ...   395.996 secs...
# Saved trial 0 (right) to C:/Users/pc/Desktop/李佳/right\trial_0_right.npy
# Saved trial 1 (left) to C:/Users/pc/Desktop/李佳/left\trial_1_left.npy
# Saved trial 2 (right) to C:/Users/pc/Desktop/李佳/right\trial_2_right.npy
# Saved trial 3 (right) to C:/Users/pc/Desktop/李佳/right\trial_3_right.npy
# Saved trial 4 (right) to C:/Users/pc/Desktop/李佳/right\trial_4_right.npy
# Saved trial 5 (right) to C:/Users/pc/Desktop/李佳/right\trial_5_right.npy
# Saved trial 6 (left) to C:/Users/pc/Desktop/李佳/left\trial_6_left.npy
# Saved trial 7 (left) to C:/Users/pc/Desktop/李佳/left\trial_7_left.npy
# Saved trial 8 (left) to C:/Users/pc/Desktop/李佳/left\trial_8_left.npy
# Saved trial 9 (right) to C:/Users/pc/Desktop/李佳/right\trial_9_right.npy
# Saved trial 10 (left) to C:/Users/pc/Desktop/李佳/left\trial_10_left.npy
# Saved trial 11 (left) to C:/Users/pc/Desktop/李佳/left\trial_11_left.npy
# Saved trial 12 (right) to C:/Users/pc/Desktop/李佳/right\trial_12_right.npy
# Saved trial 13 (right) to C:/Users/pc/Desktop/李佳/right\trial_13_right.npy
# Saved trial 14 (left) to C:/Users/pc/Desktop/李佳/left\trial_14_left.npy
# Saved trial 15 (right) to C:/Users/pc/Desktop/李佳/right\trial_15_right.npy
# Saved trial 16 (right) to C:/Users/pc/Desktop/李佳/right\trial_16_right.npy
# Saved trial 17 (right) to C:/Users/pc/Desktop/李佳/right\trial_17_right.npy
# Saved trial 18 (left) to C:/Users/pc/Desktop/李佳/left\trial_18_left.npy
# Saved trial 19 (right) to C:/Users/pc/Desktop/李佳/right\trial_19_right.npy
# Saved trial 20 (right) to C:/Users/pc/Desktop/李佳/right\trial_20_right.npy
# Saved trial 21 (right) to C:/Users/pc/Desktop/李佳/right\trial_21_right.npy
# Saved trial 22 (right) to C:/Users/pc/Desktop/李佳/right\trial_22_right.npy
# Saved trial 23 (left) to C:/Users/pc/Desktop/李佳/left\trial_23_left.npy
# Saved trial 24 (left) to C:/Users/pc/Desktop/李佳/left\trial_24_left.npy
# Saved trial 25 (right) to C:/Users/pc/Desktop/李佳/right\trial_25_right.npy
# Saved trial 26 (right) to C:/Users/pc/Desktop/李佳/right\trial_26_right.npy
# Saved trial 27 (right) to C:/Users/pc/Desktop/李佳/right\trial_27_right.npy
# Saved trial 28 (left) to C:/Users/pc/Desktop/李佳/left\trial_28_left.npy
# Saved trial 29 (right) to C:/Users/pc/Desktop/李佳/right\trial_29_right.npy
# Saved trial 30 (left) to C:/Users/pc/Desktop/李佳/left\trial_30_left.npy
# Saved trial 31 (left) to C:/Users/pc/Desktop/李佳/left\trial_31_left.npy
# Saved trial 32 (left) to C:/Users/pc/Desktop/李佳/left\trial_32_left.npy
# Saved trial 33 (right) to C:/Users/pc/Desktop/李佳/right\trial_33_right.npy
# Saved trial 34 (left) to C:/Users/pc/Desktop/李佳/left\trial_34_left.npy
# Saved trial 35 (left) to C:/Users/pc/Desktop/李佳/left\trial_35_left.npy
# Saved trial 36 (left) to C:/Users/pc/Desktop/李佳/left\trial_36_left.npy
# Saved trial 37 (right) to C:/Users/pc/Desktop/李佳/right\trial_37_right.npy
# Saved trial 38 (right) to C:/Users/pc/Desktop/李佳/right\trial_38_right.npy
# Saved trial 39 (left) to C:/Users/pc/Desktop/李佳/left\trial_39_left.npy
# Saved trial 40 (left) to C:/Users/pc/Desktop/李佳/left\trial_40_left.npy
# Saved trial 41 (left) to C:/Users/pc/Desktop/李佳/left\trial_41_left.npy
# Saved trial 42 (right) to C:/Users/pc/Desktop/李佳/right\trial_42_right.npy
# Saved trial 43 (left) to C:/Users/pc/Desktop/李佳/left\trial_43_left.npy
# Saved trial 44 (left) to C:/Users/pc/Desktop/李佳/left\trial_44_left.npy
# Saved trial 45 (right) to C:/Users/pc/Desktop/李佳/right\trial_45_right.npy
# Saved trial 46 (left) to C:/Users/pc/Desktop/李佳/left\trial_46_left.npy
# Saved trial 47 (right) to C:/Users/pc/Desktop/李佳/right\trial_47_right.npy
# Saved trial 48 (left) to C:/Users/pc/Desktop/李佳/left\trial_48_left.npy
# Saved trial 49 (right) to C:/Users/pc/Desktop/李佳/right\trial_49_right.npy
# Saved trial 50 (right) to C:/Users/pc/Desktop/李佳/right\trial_50_right.npy
# Saved trial 51 (left) to C:/Users/pc/Desktop/李佳/left\trial_51_left.npy
# Saved trial 52 (left) to C:/Users/pc/Desktop/李佳/left\trial_52_left.npy
# Saved trial 53 (left) to C:/Users/pc/Desktop/李佳/left\trial_53_left.npy
# Saved trial 54 (right) to C:/Users/pc/Desktop/李佳/right\trial_54_right.npy
# Saved trial 55 (left) to C:/Users/pc/Desktop/李佳/left\trial_55_left.npy
# Saved trial 56 (right) to C:/Users/pc/Desktop/李佳/right\trial_56_right.npy
# Saved trial 57 (left) to C:/Users/pc/Desktop/李佳/left\trial_57_left.npy
# Saved trial 58 (left) to C:/Users/pc/Desktop/李佳/left\trial_58_left.npy
# Saved trial 59 (right) to C:/Users/pc/Desktop/李佳/right\trial_59_right.npy
# Saved trial 60 (left) to C:/Users/pc/Desktop/李佳/left\trial_60_left.npy
# Saved trial 61 (left) to C:/Users/pc/Desktop/李佳/left\trial_61_left.npy
# Saved trial 62 (right) to C:/Users/pc/Desktop/李佳/right\trial_62_right.npy
# Saved trial 63 (left) to C:/Users/pc/Desktop/李佳/left\trial_63_left.npy
# Saved trial 64 (right) to C:/Users/pc/Desktop/李佳/right\trial_64_right.npy
# Saved trial 65 (right) to C:/Users/pc/Desktop/李佳/right\trial_65_right.npy
# Saved trial 66 (right) to C:/Users/pc/Desktop/李佳/right\trial_66_right.npy
# Saved trial 67 (right) to C:/Users/pc/Desktop/李佳/right\trial_67_right.npy
# Saved trial 68 (left) to C:/Users/pc/Desktop/李佳/left\trial_68_left.npy
# Saved trial 69 (right) to C:/Users/pc/Desktop/李佳/right\trial_69_right.npy
# Saved trial 70 (right) to C:/Users/pc/Desktop/李佳/right\trial_70_right.npy
# Saved trial 71 (right) to C:/Users/pc/Desktop/李佳/right\trial_71_right.npy
# Saved trial 72 (right) to C:/Users/pc/Desktop/李佳/right\trial_72_right.npy
# Saved trial 73 (left) to C:/Users/pc/Desktop/李佳/left\trial_73_left.npy
# Saved trial 74 (right) to C:/Users/pc/Desktop/李佳/right\trial_74_right.npy
# Saved trial 75 (right) to C:/Users/pc/Desktop/李佳/right\trial_75_right.npy
# Saved trial 76 (right) to C:/Users/pc/Desktop/李佳/right\trial_76_right.npy
# Saved trial 77 (right) to C:/Users/pc/Desktop/李佳/right\trial_77_right.npy
# Saved trial 78 (left) to C:/Users/pc/Desktop/李佳/left\trial_78_left.npy
# Saved trial 79 (left) to C:/Users/pc/Desktop/李佳/left\trial_79_left.npy
# Saved trial 80 (left) to C:/Users/pc/Desktop/李佳/left\trial_80_left.npy
# Saved trial 81 (left) to C:/Users/pc/Desktop/李佳/left\trial_81_left.npy
# Saved trial 82 (left) to C:/Users/pc/Desktop/李佳/left\trial_82_left.npy
# Saved trial 83 (right) to C:/Users/pc/Desktop/李佳/right\trial_83_right.npy
# Saved trial 84 (left) to C:/Users/pc/Desktop/李佳/left\trial_84_left.npy
# Saved trial 85 (left) to C:/Users/pc/Desktop/李佳/left\trial_85_left.npy
# Saved trial 86 (right) to C:/Users/pc/Desktop/李佳/right\trial_86_right.npy
# Saved trial 87 (left) to C:/Users/pc/Desktop/李佳/left\trial_87_left.npy
# Saved trial 88 (right) to C:/Users/pc/Desktop/李佳/right\trial_88_right.npy
# Saved trial 89 (left) to C:/Users/pc/Desktop/李佳/left\trial_89_left.npy
# Saved trial 90 (left) to C:/Users/pc/Desktop/李佳/left\trial_90_left.npy
# Saved trial 91 (right) to C:/Users/pc/Desktop/李佳/right\trial_91_right.npy
# Saved trial 92 (right) to C:/Users/pc/Desktop/李佳/right\trial_92_right.npy
# Saved trial 93 (left) to C:/Users/pc/Desktop/李佳/left\trial_93_left.npy
# Saved trial 94 (right) to C:/Users/pc/Desktop/李佳/right\trial_94_right.npy
# Saved trial 95 (left) to C:/Users/pc/Desktop/李佳/left\trial_95_left.npy
# Saved trial 96 (left) to C:/Users/pc/Desktop/李佳/left\trial_96_left.npy
# Saved trial 97 (left) to C:/Users/pc/Desktop/李佳/left\trial_97_left.npy
# Saved trial 98 (left) to C:/Users/pc/Desktop/李佳/left\trial_98_left.npy
